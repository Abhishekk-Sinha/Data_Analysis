# %% [markdown]
# - plt.style.use('classic')\
# - http://tonysyu.github.io/raw_content/matplotlib-style-gallery/gallery.html

# %% [markdown]
# - matplotlib, seaborn >>important from interview, plotly >> interactive, bokeh

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
x = np.random.rand(50)
y = np.random.rand(50)

# %%
x
# Out:
# array([0.01127997, 0.59642429, 0.00123445, 0.01379639, 0.16231314,
#        0.3108921 , 0.82128192, 0.26048211, 0.07097012, 0.59532031,
#        0.8310861 , 0.16238704, 0.30340408, 0.94882201, 0.31929239,
#        0.928153  , 0.0161307 , 0.68562774, 0.5749689 , 0.36296121,
#        0.47496783, 0.87157249, 0.36634317, 0.9774861 , 0.62479472,
#        0.70574532, 0.25937036, 0.66252826, 0.2615006 , 0.12082904,
#        0.58333289, 0.38019199, 0.88751973, 0.95450552, 0.7732868 ,
#        0.15397657, 0.22380855, 0.52592496, 0.42417213, 0.46010803,
#        0.19758895, 0.29636652, 0.09355515, 0.74483237, 0.6471735 ,
#        0.22310753, 0.10390154, 0.25290632, 0.28868931, 0.90572749])

# %%
y
# Out:
# array([0.7423005 , 0.84049944, 0.95595534, 0.90029882, 0.59525141,
#        0.52323885, 0.22279871, 0.38843483, 0.12119652, 0.61570906,
#        0.60162472, 0.024605  , 0.36500693, 0.96868191, 0.80479583,
#        0.7555983 , 0.39901732, 0.87889571, 0.6011267 , 0.36206474,
#        0.36455123, 0.89297851, 0.26045043, 0.98792933, 0.53000671,
#        0.61524952, 0.66247738, 0.24376537, 0.88185526, 0.7314013 ,
#        0.64498658, 0.74541405, 0.37347158, 0.54324822, 0.41336116,
#        0.1919445 , 0.62407731, 0.08598081, 0.59165746, 0.50613328,
#        0.53241788, 0.94727868, 0.72093126, 0.94042783, 0.34627904,
#        0.72830295, 0.24364164, 0.95031621, 0.51518521, 0.19793185])

# %%
plt.scatter(x,y)

# %%
df = pd.DataFrame(np.random.randn(1000), columns = ['data'], index = pd.date_range('2020/04/21', periods = 1000))

# %%
# !pip install pandas_datareader
import pandas_datareader as pdr
# Out:
# Requirement already satisfied: pandas_datareader in /usr/local/lib/python3.10/dist-packages (0.10.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from pandas_datareader) (4.9.4)
# Requirement already satisfied: pandas>=0.23 in /usr/local/lib/python3.10/dist-packages (from pandas_datareader) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from pandas_datareader) (2.31.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.23->pandas_datareader) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.23->pandas_datareader) (2023.4)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.23->pandas_datareader) (1.25.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pandas_datareader) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pandas_datareader) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pandas_datareader) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pandas_datareader) (2024.2.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=0.23->pandas_datareader) (1.16.0)

# %%
df
# Out:
#                 data
# 2020-04-21 -0.567996
# 2020-04-22  0.374043
# 2020-04-23  1.438232
# 2020-04-24  0.953537
# 2020-04-25  0.053246
# ...              ...
# 2023-01-11 -0.649570
# 2023-01-12  1.210277
# 2023-01-13 -1.330168
# 2023-01-14 -0.362242
# 2023-01-15  0.481269
#
# [1000 rows x 1 columns]

# %%
df.plot(figsize = (20, 8))
# Out:
# <Axes: >

# %%
x = np.linspace(0, 10, 100)

# %%
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
#         6.56565657,  6.66666667,  6.76767677,  6.86868687,  6.96969697,
#         7.07070707,  7.17171717,  7.27272727,  7.37373737,  7.47474747,
#         7.57575758,  7.67676768,  7.77777778,  7.87878788,  7.97979798,
#         8.08080808,  8.18181818,  8.28282828,  8.38383838,  8.48484848,
#         8.58585859,  8.68686869,  8.78787879,  8.88888889,  8.98989899,
#         9.09090909,  9.19191919,  9.29292929,  9.39393939,  9.49494949,
#         9.5959596 ,  9.6969697 ,  9.7979798 ,  9.8989899 , 10.        ])

# %%
plt.plot(x, np.sin(x))

# %%
plt.plot(x, np.cos(x))

# %%
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))

# %%
plt.plot(x, np.sin(x), '-')

# %%
plt.plot(x, np.sin(x), '--')

# %%
plt.plot(x, np.sin(x), '.-')

# %%
plt.plot(x, np.sin(x), ':')

# %%
plt.figure() # make page
plt.subplot(1, 2, 1) # 1 = one page, 2 = divided into subpart, 1 = access the 1 subpart
plt.plot(x, np.sin(x))


plt.subplot(1,2,2)
plt.plot(x, np.cos(x))

plt.show()

# %%
plt.figure()
plt.subplot(2, 2, 1)
plt.plot(x, np.sin(x))


plt.subplot(2,2,2)
plt.plot(x, np.cos(x))

plt.subplot(2,2,3)
plt.plot(x, np.tan(x))

plt.subplot(2,2,4)
plt.plot(x, np.cos(x+1))
plt.show()

# %%
plt.figure()
plt.subplot(2, 1, 1)
plt.plot(x, np.sin(x))


plt.subplot(2, 1, 2)
plt.plot(x, np.cos(x))

# %%
plt.plot(x, np.sin(x-0), color = 'blue')
plt.plot(x, np.sin(x-1), color = 'g')
plt.plot(x, np.sin(x-2), color = (1.0, 0.5, 0)) #rgb

# %%
plt.plot(x, np.sin(x-0), color = 'blue')
plt.ylim(-1.5, 1.5)
plt.xlim(1, 15)
plt.show()

# %%
plt.plot(x, np.sin(x-0), color = 'blue')
plt.ylim(-1.5, 1.5)
plt.xlim(1, 15)
plt.axis('equal')
plt.show()

# %%
plt.plot(x, np.sin(x-0), color = 'blue')
plt.ylim(-1.5, 1.5)
plt.xlim(1, 15)
plt.grid()
plt.axis('equal')
plt.show()

# %%
plt.plot(x, np.sin(x-0), color = 'blue')
plt.ylim(-1.5, 1.5)
plt.xlim(1,15)
plt.grid()
plt.title("This is sin plot before real dataset execution to understand basic syntax")
plt.axis('equal')
plt.show()

# %%
plt.plot(x, np.sin(x-0), color = 'blue', label = 'Sinx')
plt.plot(x, np.cos(x-0), color = 'red', label = 'Cosx')
plt.ylim(-1.5, 1.5)
plt.xlim(1, 15)
plt.grid()
plt.title("This is sin plot before real dataset execution to understand basic syntax")
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.legend()
plt.show()

# %%
data = np.random.randn(1000) #10 bins
plt.hist(data, bins = 20, color = 'green')
plt.show()

# %%
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
#         6.56565657,  6.66666667,  6.76767677,  6.86868687,  6.96969697,
#         7.07070707,  7.17171717,  7.27272727,  7.37373737,  7.47474747,
#         7.57575758,  7.67676768,  7.77777778,  7.87878788,  7.97979798,
#         8.08080808,  8.18181818,  8.28282828,  8.38383838,  8.48484848,
#         8.58585859,  8.68686869,  8.78787879,  8.88888889,  8.98989899,
#         9.09090909,  9.19191919,  9.29292929,  9.39393939,  9.49494949,
#         9.5959596 ,  9.6969697 ,  9.7979798 ,  9.8989899 , 10.        ])

# %%
y
# Out:
# array([0.7423005 , 0.84049944, 0.95595534, 0.90029882, 0.59525141,
#        0.52323885, 0.22279871, 0.38843483, 0.12119652, 0.61570906,
#        0.60162472, 0.024605  , 0.36500693, 0.96868191, 0.80479583,
#        0.7555983 , 0.39901732, 0.87889571, 0.6011267 , 0.36206474,
#        0.36455123, 0.89297851, 0.26045043, 0.98792933, 0.53000671,
#        0.61524952, 0.66247738, 0.24376537, 0.88185526, 0.7314013 ,
#        0.64498658, 0.74541405, 0.37347158, 0.54324822, 0.41336116,
#        0.1919445 , 0.62407731, 0.08598081, 0.59165746, 0.50613328,
#        0.53241788, 0.94727868, 0.72093126, 0.94042783, 0.34627904,
#        0.72830295, 0.24364164, 0.95031621, 0.51518521, 0.19793185])

# %%
x = np.random.rand(50)
y = np.random.rand(50)
plt.figure(figsize = (6, 2))
plt.scatter(x, y, c = 'r', alpha = .9, marker = "X")
plt.xlabel("x")
plt.ylabel("y")
plt.title("scatter plot")
plt.show()

# %%
x
# Out:
# array([0.57727915, 0.9816195 , 0.49325112, 0.20186946, 0.11485806,
#        0.39221753, 0.92176293, 0.55942203, 0.77764041, 0.49802187,
#        0.74091642, 0.49950664, 0.53787976, 0.33539105, 0.66294989,
#        0.78795011, 0.83745357, 0.22803841, 0.05472765, 0.37413801,
#        0.90963992, 0.3118865 , 0.55492432, 0.07617105, 0.27401236,
#        0.40799606, 0.01244381, 0.43587068, 0.8777849 , 0.20081367,
#        0.06896431, 0.66122178, 0.14151372, 0.81007104, 0.16084696,
#        0.53532336, 0.81153881, 0.68098655, 0.74895072, 0.78185356,
#        0.4412749 , 0.48746322, 0.4509622 , 0.79208485, 0.31558545,
#        0.55420213, 0.70984913, 0.45604531, 0.64268144, 0.90267031])

# %%
y
# Out:
# array([0.9212475 , 0.18397797, 0.47264299, 0.40355713, 0.28409201,
#        0.19960693, 0.68179856, 0.18098266, 0.24312433, 0.79102144,
#        0.95633291, 0.18591142, 0.9852282 , 0.90013503, 0.82476876,
#        0.05653683, 0.69167853, 0.51913398, 0.04253685, 0.09380924,
#        0.76855239, 0.72332056, 0.35298217, 0.0612904 , 0.3462423 ,
#        0.543234  , 0.50292339, 0.37833672, 0.93508379, 0.5682697 ,
#        0.07662677, 0.72922223, 0.0179001 , 0.72176816, 0.97869529,
#        0.47683291, 0.76744326, 0.78015532, 0.90975086, 0.82187393,
#        0.80924803, 0.87491358, 0.48916357, 0.46713686, 0.12607732,
#        0.77452668, 0.78462527, 0.05945781, 0.76092323, 0.71347523])

# %%
x = ["a", "b", "c", "d"]
y = [4, 6, 1, 2]

# %%
x
# Out:
# ['a', 'b', 'c', 'd']

# %%
y
# Out:
# [4, 6, 1, 2]

# %%
plt.figure(figsize = (6, 3))
plt.bar(x, y, color = '#FF5733')
plt.title("this is bar plot")
# Out:
# Text(0.5, 1.0, 'this is bar plot')

# %%
plt.figure(figsize = (6, 3))
plt.barh(x, y, color = '#FF5733')
plt.title("this is bar plot")
# Out:
# Text(0.5, 1.0, 'this is bar plot')

# %%
data = [1, 2, 3, 3, 3, 3, 4, 5, 6, 7, 8]
plt.hist(data)
# Out:
# (array([1., 1., 4., 0., 1., 1., 0., 1., 1., 1.]),
#  array([1. , 1.7, 2.4, 3.1, 3.8, 4.5, 5.2, 5.9, 6.6, 7.3, 8. ]),
#  <BarContainer object of 10 artists>)

# %%
#pie chart

langs = ['C', 'Python', 'Java']
students = [20, 100, 40]

plt.pie(students, labels = langs, autopct = '%1.1f%%')
plt.title("Pie chart")
plt.show()

# %% [markdown]
# # 3 d plot

# %%
x = np.random.rand(20)
y = np.random.rand(20)
z = np.random.rand(20)

fig = plt.figure()
ax = fig.add_subplot(projection = '3d')
ax.scatter(x, y, z, c = "#FF5733", alpha = .9)
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.show()

# %%
x
# Out:
# array([0.83511022, 0.41712312, 0.57837001, 0.49847745, 0.39398191,
#        0.93557053, 0.71273412, 0.39639533, 0.24737383, 0.04944626,
#        0.52598687, 0.41118572, 0.93083178, 0.76695553, 0.02862647,
#        0.51499591, 0.99414916, 0.80679765, 0.77230822, 0.17335571])

# %%
y
# Out:
# array([0.03126267, 0.02423388, 0.61752531, 0.08990622, 0.96771971,
#        0.49616317, 0.02101383, 0.81995708, 0.08280875, 0.03187507,
#        0.86366107, 0.20002891, 0.10839521, 0.84488232, 0.14757423,
#        0.91826033, 0.9483216 , 0.03955265, 0.90512914, 0.64023416])

# %%
z
# Out:
# array([0.1718163 , 0.22201492, 0.75934502, 0.84400555, 0.80208261,
#        0.65887009, 0.27541102, 0.99552929, 0.4769094 , 0.91009468,
#        0.11799623, 0.06797996, 0.150628  , 0.65344146, 0.05181511,
#        0.42529362, 0.56843909, 0.71196068, 0.97475174, 0.37757423])

# %%
import pandas as pd

data = pd.read_csv("Bank_churn.csv")
data.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
data.plot.scatter(x = 'Age', y = "Balance")

#insights
#maximum concentration >> 25-50
#maximum >>  40
#min>>0, it is present in all of the age group
# Out:
# <Axes: xlabel='Age', ylabel='Balance'>

# %%
#Age distribution
plt.title("Age dist")
plt.hist(data["Age"], color = "red")
plt.show()

# %%
plt.title("Balance dist")
plt.hist(data["Balance"], color = "red")
plt.show()

# %%
plt.title("Age dist")
plt.hist(data["Age"], color = "red")
plt.show()


plt.title("Balance dist")
plt.hist(data["Balance"], color = "red")
plt.show()

# %%
data.boxplot(column = 'Balance')
# Out:
# <Axes: >

# %%
plt.violinplot(data['Balance'])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x7ae70675e1a0>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x7ae7063e20b0>,
#  'cmins': <matplotlib.collections.LineCollection at 0x7ae706656c50>,
#  'cbars': <matplotlib.collections.LineCollection at 0x7ae7066576d0>}

# %%
import seaborn as sns

# %%
tips = sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.histplot(tips["total_bill"])
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.displot(tips["total_bill"])

# %%
sns.displot(tips["total_bill"], kde = True, bins = 30)

# %%
sns.displot(tips["total_bill"], kde = False, bins = 30)

# %%
sns.relplot(x = tips.total_bill, y = tips.tip, data = tips, hue = 'smoker')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(x = tips.total_bill, y = tips.tip, data = tips, hue = 'size')

# %%
sns.relplot(x = tips.total_bill, y = tips.tip, data = tips, style = 'smoker', hue = 'time')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.catplot(x = 'day', y = 'total_bill', data = tips)

# %%
sns.barplot(x = 'day', y= 'total_bill', data = tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.jointplot(x=tips.total_bill, y=tips.tip)

# %%
sns.jointplot(x = tips.total_bill, y = tips.tip, data= tips, kind = "reg")

# %%
sns.jointplot(x = tips.total_bill, y = tips.tip, data=tips, kind="hex")

# %%
sns.jointplot(x = tips.total_bill, y=tips.tip, data = tips, kind="kde") #contour>>meterological

# %% [markdown]
# #pairplot>> it will plot all the pairwise relationship of the dataframe

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.pairplot(tips)

# %%
sns.pairplot(tips, hue = 'smoker')

# %% [markdown]
# - https://seaborn.pydata.org/generated/seaborn.color_palette.html
# - https://seaborn.pydata.org/tutorial/color_palettes.html

# %%
sns.pairplot(tips, hue = 'smoker', palette = 'coolwarm')

# %% [markdown]
# - Boxplot >> to know outliers
# - 1, 2, 3, 4, 5, 100 >>> extreme data, for each day give me outlier for total bill

# %%
sns.boxplot(x = 'day', y = 'total_bill', data = tips, palette = 'rainbow')
# Out:
# <ipython-input-108-d5724ecc7b02>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x = 'day', y = 'total_bill', data = tips, palette = 'rainbow')
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(data=tips, palette = 'rainbow', orient= 'h')
# Out:
# <Axes: >

# %% [markdown]
# correlation >> to understand the relationship between

# %%
tips_num  = tips[['total_bill', 'tip', 'size']]

# %%
tips_num.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(tips_num.corr(), annot = True, cmap = 'coolwarm')
# Out:
# <Axes: >

# %%
sns.countplot(x = 'sex', data = tips)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.lmplot(x = 'total_bill', y = 'tip', data = tips, height = 20, aspect = 1)

# %%
sns.catplot(x = 'day', y = 'tip', data = tips, kind = 'swarm')
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3398: UserWarning: 8.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
