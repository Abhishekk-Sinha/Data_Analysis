# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px


import warnings
warnings.filterwarnings('ignore')


plt.style.use("fivethirtyeight")
# %matplotlib inline

pd.set_option('display.max_columns', 30)

# %%
df = pd.read_csv("us_perm_visas.csv")

# %%
df
# Out:
#                      add_these_pw_job_title_9089  agent_city  agent_firm_name  \
# 0                                            NaN         NaN              NaN
# 1                                            NaN         NaN              NaN
# 2                                            NaN         NaN              NaN
# 3                                            NaN         NaN              NaN
# 4                                            NaN         NaN              NaN
# ...                                          ...         ...              ...
# 47826  Computer and Information Systems Managers         NaN              NaN
# 47827                                 Pharmacist         NaN              NaN
# 47828          Software Developers, Applications         NaN              NaN
# 47829          Software Developers, Applications         NaN              NaN
# 47830      Software Developers, Systems Software         NaN              NaN
#
#        agent_state application_type        case_no  case_number  \
# 0              NaN             PERM  A-07323-97014          NaN
# 1              NaN             PERM  A-07332-99439          NaN
# 2              NaN             PERM  A-07333-99643          NaN
# 3              NaN             PERM  A-07339-01930          NaN
# 4              NaN             PERM  A-07345-03565          NaN
# ...            ...              ...            ...          ...
# 47826          NaN           ONLINE  A-12346-21591          NaN
# 47827          NaN           ONLINE  A-12346-21593          NaN
# 47828          NaN           ONLINE  A-12346-21602          NaN
# 47829          NaN           ONLINE  A-12346-21604          NaN
# 47830          NaN           ONLINE  A-12346-21606          NaN
#
#        case_received_date case_status class_of_admission  \
# 0                     NaN   Certified                J-1
# 1                     NaN      Denied                B-2
# 2                     NaN   Certified               H-1B
# 3                     NaN   Certified                B-2
# 4                     NaN   Certified                L-1
# ...                   ...         ...                ...
# 47826                 NaN   Certified               H-1B
# 47827                 NaN   Certified               H-1B
# 47828                 NaN   Certified               H-1B
# 47829                 NaN   Certified               H-1B
# 47830                 NaN   Certified               H-1B
#
#       country_of_citizenship country_of_citzenship decision_date  \
# 0                        NaN               ARMENIA    2012-02-01
# 1                        NaN                POLAND    2011-12-21
# 2                        NaN                 INDIA    2011-12-01
# 3                        NaN           SOUTH KOREA    2011-12-01
# 4                        NaN                CANADA    2012-01-26
# ...                      ...                   ...           ...
# 47826                  INDIA                   NaN    2013-04-18
# 47827                  INDIA                   NaN    2013-04-16
# 47828                  INDIA                   NaN    2013-05-07
# 47829                  INDIA                   NaN    2013-04-19
# 47830                  INDIA                   NaN    2013-05-07
#
#                       employer_address_1 employer_address_2  ...  \
# 0                      24 WEST 25 STREET          5TH FLOOR  ...
# 1                       200 BROAD STREET                NaN  ...
# 2             1054 TECHNOLOGY PARK DRIVE                NaN  ...
# 3                33-17 PRINCE ST. 2ND FL                NaN  ...
# 4                          1373 BROADWAY                NaN  ...
# ...                                  ...                ...  ...
# 47826               345 EAST MAIN STREET                NaN  ...
# 47827  2227 OLD EMMORTON ROAD, SUITE 122                NaN  ...
# 47828                   935 FIRST AVENUE                NaN  ...
# 47829               32605 W. 12 MILE RD.          SUITE 250  ...
# 47830              12335 KINGSRIDE, #401                NaN  ...
#
#       ri_layoff_in_past_six_months  ri_local_ethnic_paper_from  \
# 0                              NaN                         NaN
# 1                              NaN                         NaN
# 2                              NaN                         NaN
# 3                              NaN                         NaN
# 4                              NaN                         NaN
# ...                            ...                         ...
# 47826                          NaN                         NaN
# 47827                          NaN                         NaN
# 47828                          NaN                         NaN
# 47829                          NaN                         NaN
# 47830                          NaN                         NaN
#
#        ri_local_ethnic_paper_to ri_posted_notice_at_worksite  \
# 0                           NaN                          NaN
# 1                           NaN                          NaN
# 2                           NaN                          NaN
# 3                           NaN                          NaN
# 4                           NaN                          NaN
# ...                         ...                          ...
# 47826                       NaN                          NaN
# 47827                       NaN                          NaN
# 47828                       NaN                          NaN
# 47829                       NaN                          NaN
# 47830                       NaN                          NaN
#
#        ri_pvt_employment_firm_from  ri_pvt_employment_firm_to  \
# 0                              NaN                        NaN
# 1                              NaN                        NaN
# 2                              NaN                        NaN
# 3                              NaN                        NaN
# 4                              NaN                        NaN
# ...                            ...                        ...
# 47826                          NaN                        NaN
# 47827                          NaN                        NaN
# 47828                          NaN                        NaN
# 47829                          NaN                        NaN
# 47830                          NaN                        NaN
#
#        ri_us_workers_considered schd_a_sheepherder     us_economic_sector  \
# 0                           NaN                NaN                     IT
# 1                           NaN                NaN  Other Economic Sector
# 2                           NaN                NaN              Aerospace
# 3                           NaN                NaN  Other Economic Sector
# 4                           NaN                NaN           Advanced Mfg
# ...                         ...                ...                    ...
# 47826                       NaN                NaN           Advanced Mfg
# 47827                       NaN                NaN                 Retail
# 47828                       NaN                NaN                 Retail
# 47829                       NaN                NaN                     IT
# 47830                       NaN                NaN                    NaN
#
#        wage_offer_from_9089  wage_offer_to_9089  wage_offer_unit_of_pay_9089  \
# 0                  75629.00                 NaN                           yr
# 1                  37024.00                 NaN                           yr
# 2                  47923.00                 NaN                           yr
# 3                     10.97                 NaN                           hr
# 4                 100000.00                 NaN                           yr
# ...                     ...                 ...                          ...
# 47826                   NaN                 NaN                          NaN
# 47827                   NaN                 NaN                          NaN
# 47828                   NaN                 NaN                          NaN
# 47829                   NaN                 NaN                          NaN
# 47830                   NaN                 NaN                          NaN
#
#        wage_offered_from_9089  wage_offered_to_9089  \
# 0                         NaN                   NaN
# 1                         NaN                   NaN
# 2                         NaN                   NaN
# 3                         NaN                   NaN
# 4                         NaN                   NaN
# ...                       ...                   ...
# 47826                 96637.0                   NaN
# 47827                 88171.0                   NaN
# 47828                110000.0                   NaN
# 47829                 88254.0                   NaN
# 47830                     NaN                   NaN
#
#        wage_offered_unit_of_pay_9089
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# ...                              ...
# 47826                            NaN
# 47827                            NaN
# 47828                            NaN
# 47829                            NaN
# 47830                            NaN
#
# [47831 rows x 154 columns]

# %%
df.columns
# Out:
# Index(['add_these_pw_job_title_9089', 'agent_city', 'agent_firm_name',
#        'agent_state', 'application_type', 'case_no', 'case_number',
#        'case_received_date', 'case_status', 'class_of_admission',
#        ...
#        'ri_pvt_employment_firm_to', 'ri_us_workers_considered',
#        'schd_a_sheepherder', 'us_economic_sector', 'wage_offer_from_9089',
#        'wage_offer_to_9089', 'wage_offer_unit_of_pay_9089',
#        'wage_offered_from_9089', 'wage_offered_to_9089',
#        'wage_offered_unit_of_pay_9089'],
#       dtype='object', length=154)

# %%
df.shape
# Out:
# (47831, 154)

# %%
df. shape
# Out:
# (47831, 154)

# %%
df.isnull().sum()
# Out:
# add_these_pw_job_title_9089      20947
# agent_city                       47831
# agent_firm_name                  47831
# agent_state                      47831
# application_type                     0
#                                  ...
# wage_offer_to_9089               43182
# wage_offer_unit_of_pay_9089      27257
# wage_offered_from_9089           20578
# wage_offered_to_9089             40754
# wage_offered_unit_of_pay_9089    47831
# Length: 154, dtype: int64

# %%
df.dtypes
# Out:
# add_these_pw_job_title_9089       object
# agent_city                       float64
# agent_firm_name                  float64
# agent_state                      float64
# application_type                  object
#                                   ...
# wage_offer_to_9089               float64
# wage_offer_unit_of_pay_9089       object
# wage_offered_from_9089           float64
# wage_offered_to_9089             float64
# wage_offered_unit_of_pay_9089    float64
# Length: 154, dtype: object

# %%
df.shape
# Out:
# (47831, 154)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47831 entries, 0 to 47830
# Columns: 154 entries, add_these_pw_job_title_9089 to wage_offered_unit_of_pay_9089
# dtypes: float64(126), object(28)
# memory usage: 56.2+ MB

# %%
df.describe()
# Out:
#        agent_city  agent_firm_name  agent_state  case_number  \
# count         0.0              0.0          0.0          0.0
# mean          NaN              NaN          NaN          NaN
# std           NaN              NaN          NaN          NaN
# min           NaN              NaN          NaN          NaN
# 25%           NaN              NaN          NaN          NaN
# 50%           NaN              NaN          NaN          NaN
# 75%           NaN              NaN          NaN          NaN
# max           NaN              NaN          NaN          NaN
#
#        case_received_date  employer_country  employer_decl_info_title  \
# count                 0.0               0.0                       0.0
# mean                  NaN               NaN                       NaN
# std                   NaN               NaN                       NaN
# min                   NaN               NaN                       NaN
# 25%                   NaN               NaN                       NaN
# 50%                   NaN               NaN                       NaN
# 75%                   NaN               NaN                       NaN
# max                   NaN               NaN                       NaN
#
#        employer_num_employees  employer_phone  employer_phone_ext  \
# count                     0.0             0.0                 0.0
# mean                      NaN             NaN                 NaN
# std                       NaN             NaN                 NaN
# min                       NaN             NaN                 NaN
# 25%                       NaN             NaN                 NaN
# 50%                       NaN             NaN                 NaN
# 75%                       NaN             NaN                 NaN
# max                       NaN             NaN                 NaN
#
#        employer_yr_estab  foreign_worker_info_alt_edu_experience  \
# count                0.0                                     0.0
# mean                 NaN                                     NaN
# std                  NaN                                     NaN
# min                  NaN                                     NaN
# 25%                  NaN                                     NaN
# 50%                  NaN                                     NaN
# 75%                  NaN                                     NaN
# max                  NaN                                     NaN
#
#        foreign_worker_info_birth_country  foreign_worker_info_city  \
# count                                0.0                       0.0
# mean                                 NaN                       NaN
# std                                  NaN                       NaN
# min                                  NaN                       NaN
# 25%                                  NaN                       NaN
# 50%                                  NaN                       NaN
# 75%                                  NaN                       NaN
# max                                  NaN                       NaN
#
#        foreign_worker_info_education  ...  ri_job_search_website_from  \
# count                            0.0  ...                         0.0
# mean                             NaN  ...                         NaN
# std                              NaN  ...                         NaN
# min                              NaN  ...                         NaN
# 25%                              NaN  ...                         NaN
# 50%                              NaN  ...                         NaN
# 75%                              NaN  ...                         NaN
# max                              NaN  ...                         NaN
#
#        ri_job_search_website_to  ri_layoff_in_past_six_months  \
# count                       0.0                           0.0
# mean                        NaN                           NaN
# std                         NaN                           NaN
# min                         NaN                           NaN
# 25%                         NaN                           NaN
# 50%                         NaN                           NaN
# 75%                         NaN                           NaN
# max                         NaN                           NaN
#
#        ri_local_ethnic_paper_from  ri_local_ethnic_paper_to  \
# count                         0.0                       0.0
# mean                          NaN                       NaN
# std                           NaN                       NaN
# min                           NaN                       NaN
# 25%                           NaN                       NaN
# 50%                           NaN                       NaN
# 75%                           NaN                       NaN
# max                           NaN                       NaN
#
#        ri_posted_notice_at_worksite  ri_pvt_employment_firm_from  \
# count                           0.0                          0.0
# mean                            NaN                          NaN
# std                             NaN                          NaN
# min                             NaN                          NaN
# 25%                             NaN                          NaN
# 50%                             NaN                          NaN
# 75%                             NaN                          NaN
# max                             NaN                          NaN
#
#        ri_pvt_employment_firm_to  ri_us_workers_considered  \
# count                        0.0                       0.0
# mean                         NaN                       NaN
# std                          NaN                       NaN
# min                          NaN                       NaN
# 25%                          NaN                       NaN
# 50%                          NaN                       NaN
# 75%                          NaN                       NaN
# max                          NaN                       NaN
#
#        schd_a_sheepherder  wage_offer_from_9089  wage_offer_to_9089  \
# count                 0.0          2.057200e+04        4.649000e+03
# mean                  NaN          9.129925e+04        1.128513e+05
# std                   NaN          1.780154e+05        2.029880e+05
# min                   NaN          7.250000e+00        0.000000e+00
# 25%                   NaN          6.514800e+04        8.313800e+04
# 50%                   NaN          8.443774e+04        1.050000e+05
# 75%                   NaN          1.053730e+05        1.255600e+05
# max                   NaN          1.117584e+07        9.603360e+06
#
#        wage_offered_from_9089  wage_offered_to_9089  \
# count            2.725300e+04          7.077000e+03
# mean             9.491172e+04          1.205246e+05
# std              1.360028e+05          4.852068e+04
# min              6.770000e+00          6.770000e+00
# 25%              7.469280e+04          9.500000e+04
# 50%              9.037600e+04          1.182480e+05
# 75%              1.098000e+05          1.430006e+05
# max              1.629060e+07          1.467000e+06
#
#        wage_offered_unit_of_pay_9089
# count                            0.0
# mean                             NaN
# std                              NaN
# min                              NaN
# 25%                              NaN
# 50%                              NaN
# 75%                              NaN
# max                              NaN
#
# [8 rows x 126 columns]

# %%
df
# Out:
#                      add_these_pw_job_title_9089  agent_city  agent_firm_name  \
# 0                                            NaN         NaN              NaN
# 1                                            NaN         NaN              NaN
# 2                                            NaN         NaN              NaN
# 3                                            NaN         NaN              NaN
# 4                                            NaN         NaN              NaN
# ...                                          ...         ...              ...
# 47826  Computer and Information Systems Managers         NaN              NaN
# 47827                                 Pharmacist         NaN              NaN
# 47828          Software Developers, Applications         NaN              NaN
# 47829          Software Developers, Applications         NaN              NaN
# 47830      Software Developers, Systems Software         NaN              NaN
#
#        agent_state application_type        case_no  case_number  \
# 0              NaN             PERM  A-07323-97014          NaN
# 1              NaN             PERM  A-07332-99439          NaN
# 2              NaN             PERM  A-07333-99643          NaN
# 3              NaN             PERM  A-07339-01930          NaN
# 4              NaN             PERM  A-07345-03565          NaN
# ...            ...              ...            ...          ...
# 47826          NaN           ONLINE  A-12346-21591          NaN
# 47827          NaN           ONLINE  A-12346-21593          NaN
# 47828          NaN           ONLINE  A-12346-21602          NaN
# 47829          NaN           ONLINE  A-12346-21604          NaN
# 47830          NaN           ONLINE  A-12346-21606          NaN
#
#        case_received_date case_status class_of_admission  \
# 0                     NaN   Certified                J-1
# 1                     NaN      Denied                B-2
# 2                     NaN   Certified               H-1B
# 3                     NaN   Certified                B-2
# 4                     NaN   Certified                L-1
# ...                   ...         ...                ...
# 47826                 NaN   Certified               H-1B
# 47827                 NaN   Certified               H-1B
# 47828                 NaN   Certified               H-1B
# 47829                 NaN   Certified               H-1B
# 47830                 NaN   Certified               H-1B
#
#       country_of_citizenship country_of_citzenship decision_date  \
# 0                        NaN               ARMENIA    2012-02-01
# 1                        NaN                POLAND    2011-12-21
# 2                        NaN                 INDIA    2011-12-01
# 3                        NaN           SOUTH KOREA    2011-12-01
# 4                        NaN                CANADA    2012-01-26
# ...                      ...                   ...           ...
# 47826                  INDIA                   NaN    2013-04-18
# 47827                  INDIA                   NaN    2013-04-16
# 47828                  INDIA                   NaN    2013-05-07
# 47829                  INDIA                   NaN    2013-04-19
# 47830                  INDIA                   NaN    2013-05-07
#
#                       employer_address_1 employer_address_2  ...  \
# 0                      24 WEST 25 STREET          5TH FLOOR  ...
# 1                       200 BROAD STREET                NaN  ...
# 2             1054 TECHNOLOGY PARK DRIVE                NaN  ...
# 3                33-17 PRINCE ST. 2ND FL                NaN  ...
# 4                          1373 BROADWAY                NaN  ...
# ...                                  ...                ...  ...
# 47826               345 EAST MAIN STREET                NaN  ...
# 47827  2227 OLD EMMORTON ROAD, SUITE 122                NaN  ...
# 47828                   935 FIRST AVENUE                NaN  ...
# 47829               32605 W. 12 MILE RD.          SUITE 250  ...
# 47830              12335 KINGSRIDE, #401                NaN  ...
#
#       ri_layoff_in_past_six_months  ri_local_ethnic_paper_from  \
# 0                              NaN                         NaN
# 1                              NaN                         NaN
# 2                              NaN                         NaN
# 3                              NaN                         NaN
# 4                              NaN                         NaN
# ...                            ...                         ...
# 47826                          NaN                         NaN
# 47827                          NaN                         NaN
# 47828                          NaN                         NaN
# 47829                          NaN                         NaN
# 47830                          NaN                         NaN
#
#        ri_local_ethnic_paper_to ri_posted_notice_at_worksite  \
# 0                           NaN                          NaN
# 1                           NaN                          NaN
# 2                           NaN                          NaN
# 3                           NaN                          NaN
# 4                           NaN                          NaN
# ...                         ...                          ...
# 47826                       NaN                          NaN
# 47827                       NaN                          NaN
# 47828                       NaN                          NaN
# 47829                       NaN                          NaN
# 47830                       NaN                          NaN
#
#        ri_pvt_employment_firm_from  ri_pvt_employment_firm_to  \
# 0                              NaN                        NaN
# 1                              NaN                        NaN
# 2                              NaN                        NaN
# 3                              NaN                        NaN
# 4                              NaN                        NaN
# ...                            ...                        ...
# 47826                          NaN                        NaN
# 47827                          NaN                        NaN
# 47828                          NaN                        NaN
# 47829                          NaN                        NaN
# 47830                          NaN                        NaN
#
#        ri_us_workers_considered schd_a_sheepherder     us_economic_sector  \
# 0                           NaN                NaN                     IT
# 1                           NaN                NaN  Other Economic Sector
# 2                           NaN                NaN              Aerospace
# 3                           NaN                NaN  Other Economic Sector
# 4                           NaN                NaN           Advanced Mfg
# ...                         ...                ...                    ...
# 47826                       NaN                NaN           Advanced Mfg
# 47827                       NaN                NaN                 Retail
# 47828                       NaN                NaN                 Retail
# 47829                       NaN                NaN                     IT
# 47830                       NaN                NaN                    NaN
#
#        wage_offer_from_9089  wage_offer_to_9089  wage_offer_unit_of_pay_9089  \
# 0                  75629.00                 NaN                           yr
# 1                  37024.00                 NaN                           yr
# 2                  47923.00                 NaN                           yr
# 3                     10.97                 NaN                           hr
# 4                 100000.00                 NaN                           yr
# ...                     ...                 ...                          ...
# 47826                   NaN                 NaN                          NaN
# 47827                   NaN                 NaN                          NaN
# 47828                   NaN                 NaN                          NaN
# 47829                   NaN                 NaN                          NaN
# 47830                   NaN                 NaN                          NaN
#
#        wage_offered_from_9089  wage_offered_to_9089  \
# 0                         NaN                   NaN
# 1                         NaN                   NaN
# 2                         NaN                   NaN
# 3                         NaN                   NaN
# 4                         NaN                   NaN
# ...                       ...                   ...
# 47826                 96637.0                   NaN
# 47827                 88171.0                   NaN
# 47828                110000.0                   NaN
# 47829                 88254.0                   NaN
# 47830                     NaN                   NaN
#
#        wage_offered_unit_of_pay_9089
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# ...                              ...
# 47826                            NaN
# 47827                            NaN
# 47828                            NaN
# 47829                            NaN
# 47830                            NaN
#
# [47831 rows x 154 columns]

# %%
df.columns.values
# Out:
# array(['add_these_pw_job_title_9089', 'agent_city', 'agent_firm_name',
#        'agent_state', 'application_type', 'case_no', 'case_number',
#        'case_received_date', 'case_status', 'class_of_admission',
#        'country_of_citizenship', 'country_of_citzenship', 'decision_date',
#        'employer_address_1', 'employer_address_2', 'employer_city',
#        'employer_country', 'employer_decl_info_title', 'employer_name',
#        'employer_num_employees', 'employer_phone', 'employer_phone_ext',
#        'employer_postal_code', 'employer_state', 'employer_yr_estab',
#        'foreign_worker_info_alt_edu_experience',
#        'foreign_worker_info_birth_country', 'foreign_worker_info_city',
#        'foreign_worker_info_education',
#        'foreign_worker_info_education_other', 'foreign_worker_info_inst',
#        'foreign_worker_info_major', 'foreign_worker_info_postal_code',
#        'foreign_worker_info_rel_occup_exp',
#        'foreign_worker_info_req_experience', 'foreign_worker_info_state',
#        'foreign_worker_info_training_comp',
#        'foreign_worker_ownership_interest',
#        'foreign_worker_yr_rel_edu_completed',
#        'fw_info_alt_edu_experience', 'fw_info_birth_country',
#        'fw_info_education_other', 'fw_info_postal_code',
#        'fw_info_rel_occup_exp', 'fw_info_req_experience',
#        'fw_info_training_comp', 'fw_info_yr_rel_edu_completed',
#        'fw_ownership_interest', 'ji_foreign_worker_live_on_premises',
#        'ji_fw_live_on_premises', 'ji_live_in_dom_svc_contract',
#        'ji_live_in_domestic_service',
#        'ji_offered_to_sec_j_foreign_worker', 'ji_offered_to_sec_j_fw',
#        'job_info_alt_cmb_ed_oth_yrs', 'job_info_alt_combo_ed',
#        'job_info_alt_combo_ed_exp', 'job_info_alt_combo_ed_other',
#        'job_info_alt_field', 'job_info_alt_field_name',
#        'job_info_alt_occ', 'job_info_alt_occ_job_title',
#        'job_info_alt_occ_num_months', 'job_info_combo_occupation',
#        'job_info_education', 'job_info_education_other',
#        'job_info_experience', 'job_info_experience_num_months',
#        'job_info_foreign_ed', 'job_info_foreign_lang_req',
#        'job_info_job_req_normal', 'job_info_job_title', 'job_info_major',
#        'job_info_training', 'job_info_training_field',
#        'job_info_training_num_months', 'job_info_work_city',
#        'job_info_work_postal_code', 'job_info_work_state',
#        'naics_2007_us_code', 'naics_2007_us_title', 'naics_code',
#        'naics_title', 'naics_us_code', 'naics_us_code_2007',
#        'naics_us_title', 'naics_us_title_2007', 'orig_case_no',
#        'orig_file_date', 'preparer_info_emp_completed',
#        'preparer_info_title', 'pw_amount_9089', 'pw_determ_date',
#        'pw_expire_date', 'pw_job_title_908', 'pw_job_title_9089',
#        'pw_level_9089', 'pw_soc_code', 'pw_soc_title',
#        'pw_source_name_9089', 'pw_source_name_other_9089', 'pw_track_num',
#        'pw_unit_of_pay_9089', 'rec_info_barg_rep_notified',
#        'recr_info_barg_rep_notified', 'recr_info_coll_teach_comp_proc',
#        'recr_info_coll_univ_teacher', 'recr_info_employer_rec_payment',
#        'recr_info_first_ad_start', 'recr_info_job_fair_from',
#        'recr_info_job_fair_to', 'recr_info_on_campus_recr_from',
#        'recr_info_on_campus_recr_to', 'recr_info_pro_org_advert_from',
#        'recr_info_pro_org_advert_to', 'recr_info_prof_org_advert_from',
#        'recr_info_prof_org_advert_to', 'recr_info_professional_occ',
#        'recr_info_radio_tv_ad_from', 'recr_info_radio_tv_ad_to',
#        'recr_info_second_ad_start', 'recr_info_sunday_newspaper',
#        'recr_info_swa_job_order_end', 'recr_info_swa_job_order_start',
#        'refile', 'ri_1st_ad_newspaper_name', 'ri_2nd_ad_newspaper_name',
#        'ri_2nd_ad_newspaper_or_journal', 'ri_campus_placement_from',
#        'ri_campus_placement_to', 'ri_coll_tch_basic_process',
#        'ri_coll_teach_pro_jnl', 'ri_coll_teach_select_date',
#        'ri_employee_referral_prog_from', 'ri_employee_referral_prog_to',
#        'ri_employer_web_post_from', 'ri_employer_web_post_to',
#        'ri_job_search_website_from', 'ri_job_search_website_to',
#        'ri_layoff_in_past_six_months', 'ri_local_ethnic_paper_from',
#        'ri_local_ethnic_paper_to', 'ri_posted_notice_at_worksite',
#        'ri_pvt_employment_firm_from', 'ri_pvt_employment_firm_to',
#        'ri_us_workers_considered', 'schd_a_sheepherder',
#        'us_economic_sector', 'wage_offer_from_9089', 'wage_offer_to_9089',
#        'wage_offer_unit_of_pay_9089', 'wage_offered_from_9089',
#        'wage_offered_to_9089', 'wage_offered_unit_of_pay_9089'],
#       dtype=object)

# %%
df['case_number']
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#          ..
# 47826   NaN
# 47827   NaN
# 47828   NaN
# 47829   NaN
# 47830   NaN
# Name: case_number, Length: 47831, dtype: float64

# %%
df['case_no']
# Out:
# 0        A-07323-97014
# 1        A-07332-99439
# 2        A-07333-99643
# 3        A-07339-01930
# 4        A-07345-03565
#              ...
# 47826    A-12346-21591
# 47827    A-12346-21593
# 47828    A-12346-21602
# 47829    A-12346-21604
# 47830    A-12346-21606
# Name: case_no, Length: 47831, dtype: object

# %%
df.drop("case_no", axis =1, inplace = True)

# %%
df.columns.values
# Out:
# array(['add_these_pw_job_title_9089', 'agent_city', 'agent_firm_name',
#        'agent_state', 'application_type', 'case_number',
#        'case_received_date', 'case_status', 'class_of_admission',
#        'country_of_citizenship', 'country_of_citzenship', 'decision_date',
#        'employer_address_1', 'employer_address_2', 'employer_city',
#        'employer_country', 'employer_decl_info_title', 'employer_name',
#        'employer_num_employees', 'employer_phone', 'employer_phone_ext',
#        'employer_postal_code', 'employer_state', 'employer_yr_estab',
#        'foreign_worker_info_alt_edu_experience',
#        'foreign_worker_info_birth_country', 'foreign_worker_info_city',
#        'foreign_worker_info_education',
#        'foreign_worker_info_education_other', 'foreign_worker_info_inst',
#        'foreign_worker_info_major', 'foreign_worker_info_postal_code',
#        'foreign_worker_info_rel_occup_exp',
#        'foreign_worker_info_req_experience', 'foreign_worker_info_state',
#        'foreign_worker_info_training_comp',
#        'foreign_worker_ownership_interest',
#        'foreign_worker_yr_rel_edu_completed',
#        'fw_info_alt_edu_experience', 'fw_info_birth_country',
#        'fw_info_education_other', 'fw_info_postal_code',
#        'fw_info_rel_occup_exp', 'fw_info_req_experience',
#        'fw_info_training_comp', 'fw_info_yr_rel_edu_completed',
#        'fw_ownership_interest', 'ji_foreign_worker_live_on_premises',
#        'ji_fw_live_on_premises', 'ji_live_in_dom_svc_contract',
#        'ji_live_in_domestic_service',
#        'ji_offered_to_sec_j_foreign_worker', 'ji_offered_to_sec_j_fw',
#        'job_info_alt_cmb_ed_oth_yrs', 'job_info_alt_combo_ed',
#        'job_info_alt_combo_ed_exp', 'job_info_alt_combo_ed_other',
#        'job_info_alt_field', 'job_info_alt_field_name',
#        'job_info_alt_occ', 'job_info_alt_occ_job_title',
#        'job_info_alt_occ_num_months', 'job_info_combo_occupation',
#        'job_info_education', 'job_info_education_other',
#        'job_info_experience', 'job_info_experience_num_months',
#        'job_info_foreign_ed', 'job_info_foreign_lang_req',
#        'job_info_job_req_normal', 'job_info_job_title', 'job_info_major',
#        'job_info_training', 'job_info_training_field',
#        'job_info_training_num_months', 'job_info_work_city',
#        'job_info_work_postal_code', 'job_info_work_state',
#        'naics_2007_us_code', 'naics_2007_us_title', 'naics_code',
#        'naics_title', 'naics_us_code', 'naics_us_code_2007',
#        'naics_us_title', 'naics_us_title_2007', 'orig_case_no',
#        'orig_file_date', 'preparer_info_emp_completed',
#        'preparer_info_title', 'pw_amount_9089', 'pw_determ_date',
#        'pw_expire_date', 'pw_job_title_908', 'pw_job_title_9089',
#        'pw_level_9089', 'pw_soc_code', 'pw_soc_title',
#        'pw_source_name_9089', 'pw_source_name_other_9089', 'pw_track_num',
#        'pw_unit_of_pay_9089', 'rec_info_barg_rep_notified',
#        'recr_info_barg_rep_notified', 'recr_info_coll_teach_comp_proc',
#        'recr_info_coll_univ_teacher', 'recr_info_employer_rec_payment',
#        'recr_info_first_ad_start', 'recr_info_job_fair_from',
#        'recr_info_job_fair_to', 'recr_info_on_campus_recr_from',
#        'recr_info_on_campus_recr_to', 'recr_info_pro_org_advert_from',
#        'recr_info_pro_org_advert_to', 'recr_info_prof_org_advert_from',
#        'recr_info_prof_org_advert_to', 'recr_info_professional_occ',
#        'recr_info_radio_tv_ad_from', 'recr_info_radio_tv_ad_to',
#        'recr_info_second_ad_start', 'recr_info_sunday_newspaper',
#        'recr_info_swa_job_order_end', 'recr_info_swa_job_order_start',
#        'refile', 'ri_1st_ad_newspaper_name', 'ri_2nd_ad_newspaper_name',
#        'ri_2nd_ad_newspaper_or_journal', 'ri_campus_placement_from',
#        'ri_campus_placement_to', 'ri_coll_tch_basic_process',
#        'ri_coll_teach_pro_jnl', 'ri_coll_teach_select_date',
#        'ri_employee_referral_prog_from', 'ri_employee_referral_prog_to',
#        'ri_employer_web_post_from', 'ri_employer_web_post_to',
#        'ri_job_search_website_from', 'ri_job_search_website_to',
#        'ri_layoff_in_past_six_months', 'ri_local_ethnic_paper_from',
#        'ri_local_ethnic_paper_to', 'ri_posted_notice_at_worksite',
#        'ri_pvt_employment_firm_from', 'ri_pvt_employment_firm_to',
#        'ri_us_workers_considered', 'schd_a_sheepherder',
#        'us_economic_sector', 'wage_offer_from_9089', 'wage_offer_to_9089',
#        'wage_offer_unit_of_pay_9089', 'wage_offered_from_9089',
#        'wage_offered_to_9089', 'wage_offered_unit_of_pay_9089'],
#       dtype=object)

# %%
df.case_status
# Out:
# 0        Certified
# 1           Denied
# 2        Certified
# 3        Certified
# 4        Certified
#            ...
# 47826    Certified
# 47827    Certified
# 47828    Certified
# 47829    Certified
# 47830    Certified
# Name: case_status, Length: 47831, dtype: object

# %%
df = df[df["case_status"] != "Withdrawn"]  #withdarawn application should not be analysed

# %%
df.case_status.unique()
# Out:
# array(['Certified', 'Denied', 'Certified-Expired'], dtype=object)

# %%
df
# Out:
#                      add_these_pw_job_title_9089  agent_city  agent_firm_name  \
# 0                                            NaN         NaN              NaN
# 1                                            NaN         NaN              NaN
# 2                                            NaN         NaN              NaN
# 3                                            NaN         NaN              NaN
# 4                                            NaN         NaN              NaN
# ...                                          ...         ...              ...
# 47826  Computer and Information Systems Managers         NaN              NaN
# 47827                                 Pharmacist         NaN              NaN
# 47828          Software Developers, Applications         NaN              NaN
# 47829          Software Developers, Applications         NaN              NaN
# 47830      Software Developers, Systems Software         NaN              NaN
#
#        agent_state application_type  case_number  case_received_date  \
# 0              NaN             PERM          NaN                 NaN
# 1              NaN             PERM          NaN                 NaN
# 2              NaN             PERM          NaN                 NaN
# 3              NaN             PERM          NaN                 NaN
# 4              NaN             PERM          NaN                 NaN
# ...            ...              ...          ...                 ...
# 47826          NaN           ONLINE          NaN                 NaN
# 47827          NaN           ONLINE          NaN                 NaN
# 47828          NaN           ONLINE          NaN                 NaN
# 47829          NaN           ONLINE          NaN                 NaN
# 47830          NaN           ONLINE          NaN                 NaN
#
#       case_status class_of_admission country_of_citizenship  \
# 0       Certified                J-1                    NaN
# 1          Denied                B-2                    NaN
# 2       Certified               H-1B                    NaN
# 3       Certified                B-2                    NaN
# 4       Certified                L-1                    NaN
# ...           ...                ...                    ...
# 47826   Certified               H-1B                  INDIA
# 47827   Certified               H-1B                  INDIA
# 47828   Certified               H-1B                  INDIA
# 47829   Certified               H-1B                  INDIA
# 47830   Certified               H-1B                  INDIA
#
#       country_of_citzenship decision_date                 employer_address_1  \
# 0                   ARMENIA    2012-02-01                  24 WEST 25 STREET
# 1                    POLAND    2011-12-21                   200 BROAD STREET
# 2                     INDIA    2011-12-01         1054 TECHNOLOGY PARK DRIVE
# 3               SOUTH KOREA    2011-12-01            33-17 PRINCE ST. 2ND FL
# 4                    CANADA    2012-01-26                      1373 BROADWAY
# ...                     ...           ...                                ...
# 47826                   NaN    2013-04-18               345 EAST MAIN STREET
# 47827                   NaN    2013-04-16  2227 OLD EMMORTON ROAD, SUITE 122
# 47828                   NaN    2013-05-07                   935 FIRST AVENUE
# 47829                   NaN    2013-04-19               32605 W. 12 MILE RD.
# 47830                   NaN    2013-05-07              12335 KINGSRIDE, #401
#
#       employer_address_2     employer_city  ...  ri_layoff_in_past_six_months  \
# 0              5TH FLOOR          NEW YORK  ...                           NaN
# 1                    NaN         CARLSTADT  ...                           NaN
# 2                    NaN        GLEN ALLEN  ...                           NaN
# 3                    NaN          FLUSHING  ...                           NaN
# 4                    NaN            ALBANY  ...                           NaN
# ...                  ...               ...  ...                           ...
# 47826                NaN            WARSAW  ...                           NaN
# 47827                NaN           BEL AIR  ...                           NaN
# 47828                NaN   KING OF PRUSSIA  ...                           NaN
# 47829          SUITE 250  FARMINGTON HILLS  ...                           NaN
# 47830                NaN           HOUSTON  ...                           NaN
#
#        ri_local_ethnic_paper_from ri_local_ethnic_paper_to  \
# 0                             NaN                      NaN
# 1                             NaN                      NaN
# 2                             NaN                      NaN
# 3                             NaN                      NaN
# 4                             NaN                      NaN
# ...                           ...                      ...
# 47826                         NaN                      NaN
# 47827                         NaN                      NaN
# 47828                         NaN                      NaN
# 47829                         NaN                      NaN
# 47830                         NaN                      NaN
#
#        ri_posted_notice_at_worksite  ri_pvt_employment_firm_from  \
# 0                               NaN                          NaN
# 1                               NaN                          NaN
# 2                               NaN                          NaN
# 3                               NaN                          NaN
# 4                               NaN                          NaN
# ...                             ...                          ...
# 47826                           NaN                          NaN
# 47827                           NaN                          NaN
# 47828                           NaN                          NaN
# 47829                           NaN                          NaN
# 47830                           NaN                          NaN
#
#        ri_pvt_employment_firm_to ri_us_workers_considered schd_a_sheepherder  \
# 0                            NaN                      NaN                NaN
# 1                            NaN                      NaN                NaN
# 2                            NaN                      NaN                NaN
# 3                            NaN                      NaN                NaN
# 4                            NaN                      NaN                NaN
# ...                          ...                      ...                ...
# 47826                        NaN                      NaN                NaN
# 47827                        NaN                      NaN                NaN
# 47828                        NaN                      NaN                NaN
# 47829                        NaN                      NaN                NaN
# 47830                        NaN                      NaN                NaN
#
#           us_economic_sector  wage_offer_from_9089  wage_offer_to_9089  \
# 0                         IT              75629.00                 NaN
# 1      Other Economic Sector              37024.00                 NaN
# 2                  Aerospace              47923.00                 NaN
# 3      Other Economic Sector                 10.97                 NaN
# 4               Advanced Mfg             100000.00                 NaN
# ...                      ...                   ...                 ...
# 47826           Advanced Mfg                   NaN                 NaN
# 47827                 Retail                   NaN                 NaN
# 47828                 Retail                   NaN                 NaN
# 47829                     IT                   NaN                 NaN
# 47830                    NaN                   NaN                 NaN
#
#        wage_offer_unit_of_pay_9089  wage_offered_from_9089  \
# 0                               yr                     NaN
# 1                               yr                     NaN
# 2                               yr                     NaN
# 3                               hr                     NaN
# 4                               yr                     NaN
# ...                            ...                     ...
# 47826                          NaN                 96637.0
# 47827                          NaN                 88171.0
# 47828                          NaN                110000.0
# 47829                          NaN                 88254.0
# 47830                          NaN                     NaN
#
#        wage_offered_to_9089  wage_offered_unit_of_pay_9089
# 0                       NaN                            NaN
# 1                       NaN                            NaN
# 2                       NaN                            NaN
# 3                       NaN                            NaN
# 4                       NaN                            NaN
# ...                     ...                            ...
# 47826                   NaN                            NaN
# 47827                   NaN                            NaN
# 47828                   NaN                            NaN
# 47829                   NaN                            NaN
# 47830                   NaN                            NaN
#
# [46474 rows x 153 columns]

# %%
df.loc[df.case_status == 'Certified-Expired', 'case_status'] = 'Certified'

# %%
df.case_status.unique()
# Out:
# array(['Certified', 'Denied'], dtype=object)

# %%
df.case_status.value_counts(normalize = True)
# Out:
# Certified    0.934953
# Denied       0.065047
# Name: case_status, dtype: float64

# %%
#insights >>  only 7% people were denied

# %%
df.dropna(axis = 1, how='all', inplace = True)

# %%
df.dropna(axis = 0, how='all', inplace = True)

# %%
df.shape
# Out:
# (46474, 32)

# %%
df.columns
# Out:
# Index(['add_these_pw_job_title_9089', 'application_type', 'case_status',
#        'class_of_admission', 'country_of_citizenship', 'country_of_citzenship',
#        'decision_date', 'employer_address_1', 'employer_address_2',
#        'employer_city', 'employer_name', 'employer_postal_code',
#        'employer_state', 'job_info_work_city', 'job_info_work_state',
#        'naics_2007_us_code', 'naics_2007_us_title', 'naics_us_code_2007',
#        'naics_us_title_2007', 'pw_amount_9089', 'pw_job_title_9089',
#        'pw_level_9089', 'pw_soc_code', 'pw_soc_title', 'pw_source_name_9089',
#        'pw_unit_of_pay_9089', 'us_economic_sector', 'wage_offer_from_9089',
#        'wage_offer_to_9089', 'wage_offer_unit_of_pay_9089',
#        'wage_offered_from_9089', 'wage_offered_to_9089'],
#       dtype='object')

# %%
df.application_type
# Out:
# 0          PERM
# 1          PERM
# 2          PERM
# 3          PERM
# 4          PERM
#           ...
# 47826    ONLINE
# 47827    ONLINE
# 47828    ONLINE
# 47829    ONLINE
# 47830    ONLINE
# Name: application_type, Length: 46474, dtype: object

# %%
df['application_type'].value_counts().plot(kind = 'bar', color = 'yellow')
# Out:
# <Axes: >

# %%
sns.countplot(data = df, x = 'application_type')
# Out:
# <Axes: xlabel='application_type', ylabel='count'>

# %%
df.columns
# Out:
# Index(['add_these_pw_job_title_9089', 'application_type', 'case_status',
#        'class_of_admission', 'country_of_citizenship', 'country_of_citzenship',
#        'decision_date', 'employer_address_1', 'employer_address_2',
#        'employer_city', 'employer_name', 'employer_postal_code',
#        'employer_state', 'job_info_work_city', 'job_info_work_state',
#        'naics_2007_us_code', 'naics_2007_us_title', 'naics_us_code_2007',
#        'naics_us_title_2007', 'pw_amount_9089', 'pw_job_title_9089',
#        'pw_level_9089', 'pw_soc_code', 'pw_soc_title', 'pw_source_name_9089',
#        'pw_unit_of_pay_9089', 'us_economic_sector', 'wage_offer_from_9089',
#        'wage_offer_to_9089', 'wage_offer_unit_of_pay_9089',
#        'wage_offered_from_9089', 'wage_offered_to_9089'],
#       dtype='object')

# %%
df.us_economic_sector
# Out:
# 0                           IT
# 1        Other Economic Sector
# 2                    Aerospace
# 3        Other Economic Sector
# 4                 Advanced Mfg
#                  ...
# 47826             Advanced Mfg
# 47827                   Retail
# 47828                   Retail
# 47829                       IT
# 47830                      NaN
# Name: us_economic_sector, Length: 46474, dtype: object

# %%
economic_sector = df['us_economic_sector'].value_counts()

# %%
economic_sector
# Out:
# IT                       17431
# Advanced Mfg              6387
# Other Economic Sector     5741
# Finance                   3308
# Educational Services      3157
# Health Care               2529
# Aerospace                 1449
# Retail                    1397
# Hospitality                825
# Construction               560
# Automotive                 424
# Energy                     413
# Transportation             363
# Agribusiness               217
# Biotechnology              152
# Geospatial                  54
# Homeland Security           22
# Name: us_economic_sector, dtype: int64

# %%
plt.figure(figsize = (8,8))
plt.pie(economic_sector, labels = economic_sector.index, autopct = '%1.1f%%')
plt.show()

# %%
#insights for above chart you will get US visa IT

df['decision_date'] = pd.to_datetime(df['decision_date'])
df['year'] = df['decision_date'].dt.year

# %%
df['year']
# Out:
# 0        2012
# 1        2011
# 2        2011
# 3        2011
# 4        2012
#          ...
# 47826    2013
# 47827    2013
# 47828    2013
# 47829    2013
# 47830    2013
# Name: year, Length: 46474, dtype: int64

# %%
fig, ax = plt.subplots(figsize = (10, 8))

sns.countplot(x = 'year', hue = 'case_status', data = df)
ax.set(xlabel = "Visa application year", ylabel = "No. of applications")
plt.show()

# %%
#insights as application increase, denied and accepted both increasing

fig, ax = plt.subplots(figsize  = (10, 8))

sns.countplot(x = 'employer_city', hue = 'year', data = df, order = df.employer_city.value_counts().iloc[:10].index)
ax.set(xlabel = "Visa application year", ylabel = "No of application")
plt.xticks(rotation = 90)
plt.show()
